# %% [markdown]
# ## KNN
# #### 필요한 패키지를 불러온다:

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split,RandomizedSearchCV, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics, preprocessing
from scipy.stats import itemfreq

# %% [markdown]
# #### 데이터를 불러온다:

# %%
os.chdir(r"C:\Users\bit\Desktop\머신러닝 알고리즘과 응용 2\data")

# %%
# df = pd.read_csv('data_spam.csv', header='infer',encoding='ISO-8859-1')
df = pd.read_csv('data_spam.csv', header='infer',encoding='latin1')

# %%
df.shape
# Out:
# (1000, 63)

# %%
df.head(5)
# Out:
#    email_id is_spam  word_freq_will  word_freq_original  word_freq_415  \
# 0      3227      no            1.06                0.26            0.0
# 1      2331      no            0.00                0.00            0.0
# 2      1899     yes            0.42                0.00            0.0
# 3      1387      no            0.00                0.00            0.0
# 4      3555      no            1.94                0.00            0.0
#
#    word_freq_mail  char_freq_#  char_freq_$  word_freq_internet  \
# 0            0.00          0.0         0.00                0.00
# 1            1.40          0.0         0.00                0.00
# 2            0.42          0.0         0.39                0.00
# 3            0.00          0.0         0.00                2.07
# 4            0.00          0.0         0.00                0.00
#
#    word_freq_edu     ...       word_freq_receive  word_freq_000  \
# 0            0.0     ...                    0.00           0.00
# 1            0.0     ...                    0.00           0.00
# 2            0.0     ...                    0.42           3.38
# 3            0.0     ...                    0.00           0.00
# 4            0.0     ...                    0.00           0.00
#
#    capital_run_length_average  word_freq_address  word_freq_george  \
# 0                       2.646               0.00               0.0
# 1                       3.875               0.00               1.4
# 2                      26.405               0.00               0.0
# 3                       1.523               0.00               0.0
# 4                       1.197               0.27               0.0
#
#    word_freq_cs  word_freq_random  word_freq_conference  word_freq_technology  \
# 0           0.0                 0                   0.0                  0.00
# 1           0.0                 0                   0.0                  0.00
# 2           0.0                 0                   0.0                  0.42
# 3           0.0                 0                   0.0                  0.00
# 4           0.0                 0                   0.0                  0.00
#
#    char_freq_(
# 0        0.039
# 1        0.220
# 2        0.097
# 3        0.144
# 4        0.000
#
# [5 rows x 63 columns]

# %%
X=np.array(df.drop(columns=['is_spam', 'email_id'])) # 스팸빼고
Y=np.array(df.is_spam) # 스팸
header = df.columns
headerX = df.drop(columns=['is_spam', 'email_id']).columns

# %% [markdown]
# #### 통계적 요약과 시각화:

# %%
table = itemfreq(Y)
plt.bar(table[:,0],table[:,1],color = 'blue')
plt.title('Category Frequency')
plt.show()
table
# Out:
# D:\Users\bit\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `itemfreq` is deprecated!
# `itemfreq` is deprecated and will be removed in a future version. Use instead `np.unique(..., return_counts=True)`
#   """Entry point for launching an IPython kernel.
# array([['no', 736],
#        ['yes', 264]], dtype=object)

# %% [markdown]
# 'yes', 'no' 레이블을 숫자로 변환:

# %%
Y = LE.fit_transform(Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f8d849044dde> in <module>()
# ----> 1 Y = LE.fit_transform(Y)
#
# NameError: name 'LE' is not defined

# %%
table = itemfreq(Y)
table
# Out:
# D:\Users\bit\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `itemfreq` is deprecated!
# `itemfreq` is deprecated and will be removed in a future version. Use instead `np.unique(..., return_counts=True)`
#   """Entry point for launching an IPython kernel.
# array([['no', 736],
#        ['yes', 264]], dtype=object)

# %% [markdown]
# NaN이 있으면 채워 넣음:

# %%
IPT = preprocessing.Imputer() #인퓨터 =결측치 제거
X = IPT.fit_transform(X)

# %% [markdown]
# #### 통계적 요약 및 데이터 전처리:

# %%
np.round(df.describe(),5)
# Out:
#          email_id  word_freq_will  word_freq_original  word_freq_415  \
# count  1000.00000      1000.00000          1000.00000     1000.00000
# mean   2271.12200         0.54098             0.04150        0.05178
# std    1326.76229         0.89535             0.20304        0.34905
# min       1.00000         0.00000             0.00000        0.00000
# 25%    1100.25000         0.00000             0.00000        0.00000
# 50%    2270.00000         0.00000             0.00000        0.00000
# 75%    3408.25000         0.78000             0.00000        0.00000
# max    4600.00000         6.45000             3.57000        4.76000
#
#        word_freq_mail  char_freq_#  char_freq_$  word_freq_internet  \
# count      1000.00000   1000.00000   1000.00000          1000.00000
# mean          0.22945      0.02844      0.06392             0.08684
# std           0.56884      0.17513      0.23364             0.33691
# min           0.00000      0.00000      0.00000             0.00000
# 25%           0.00000      0.00000      0.00000             0.00000
# 50%           0.00000      0.00000      0.00000             0.00000
# 75%           0.11250      0.00000      0.01650             0.00000
# max           5.26000      3.87900      4.01700             4.62000
#
#        word_freq_edu  word_freq_hp     ...       word_freq_receive  \
# count     1000.00000    1000.00000     ...              1000.00000
# mean         0.18903       0.57713     ...                 0.04496
# std          0.99936       1.50915     ...                 0.18222
# min          0.00000       0.00000     ...                 0.00000
# 25%          0.00000       0.00000     ...                 0.00000
# 50%          0.00000       0.00000     ...                 0.00000
# 75%          0.00000       0.29250     ...                 0.00000
# max         22.05000      16.66000     ...                 2.00000
#
#        word_freq_000  capital_run_length_average  word_freq_address  \
# count     1000.00000                  1000.00000         1000.00000
# mean         0.07956                     5.30300            0.20846
# std          0.31807                    40.07844            1.30897
# min          0.00000                     1.00000            0.00000
# 25%          0.00000                     1.52300            0.00000
# 50%          0.00000                     2.10300            0.00000
# 75%          0.00000                     3.26075            0.00000
# max          3.38000                  1021.50000           14.28000
#
#        word_freq_george  word_freq_cs  word_freq_random  word_freq_conference  \
# count        1000.00000         965.0            1000.0            1000.00000
# mean            0.98416           0.0               0.0               0.05158
# std             3.67285           0.0               0.0               0.46425
# min             0.00000           0.0               0.0               0.00000
# 25%             0.00000           0.0               0.0               0.00000
# 50%             0.00000           0.0               0.0               0.00000
# 75%             0.00000           0.0               0.0               0.00000
# max            33.33000           0.0               0.0              10.00000
#
#        word_freq_technology  char_freq_(
# count            1000.00000   1000.00000
# mean                0.10063      0.14098
# std                 0.40997      0.23535
# min                 0.00000      0.00000
# 25%                 0.00000      0.00000
# 50%                 0.00000      0.06400
# 75%                 0.00000      0.18425
# max                 4.76000      2.94100
#
# [8 rows x 62 columns]

# %%
X = preprocessing.scale(X) # 정규화

# %%
np.round(pd.DataFrame(X,columns=headerX).describe(),3)
# Out:
#        word_freq_will  word_freq_original  word_freq_415  word_freq_mail  \
# count        1000.000            1000.000       1000.000        1000.000
# mean            0.000              -0.000         -0.000           0.000
# std             1.001               1.001          1.001           1.001
# min            -0.605              -0.204         -0.148          -0.404
# 25%            -0.605              -0.204         -0.148          -0.404
# 50%            -0.605              -0.204         -0.148          -0.404
# 75%             0.267              -0.204         -0.148          -0.206
# max             6.603              17.387         13.496           8.848
#
#        char_freq_#  char_freq_$  word_freq_internet  word_freq_edu  \
# count     1000.000     1000.000            1000.000       1000.000
# mean        -0.000        0.000               0.000          0.000
# std          1.001        1.001               1.001          1.001
# min         -0.162       -0.274              -0.258         -0.189
# 25%         -0.162       -0.274              -0.258         -0.189
# 50%         -0.162       -0.274              -0.258         -0.189
# 75%         -0.162       -0.203              -0.258         -0.189
# max         21.998       16.928              13.462         21.886
#
#        word_freq_hp  word_freq_lab     ...       word_freq_receive  \
# count      1000.000       1000.000     ...                1000.000
# mean          0.000          0.000     ...                  -0.000
# std           1.001          1.001     ...                   1.001
# min          -0.383         -0.179     ...                  -0.247
# 25%          -0.383         -0.179     ...                  -0.247
# 50%          -0.383         -0.179     ...                  -0.247
# 75%          -0.189         -0.179     ...                  -0.247
# max          10.662         15.630     ...                  10.734
#
#        word_freq_000  capital_run_length_average  word_freq_address  \
# count       1000.000                    1000.000           1000.000
# mean           0.000                       0.000              0.000
# std            1.001                       1.001              1.001
# min           -0.250                      -0.107             -0.159
# 25%           -0.250                      -0.094             -0.159
# 50%           -0.250                      -0.080             -0.159
# 75%           -0.250                      -0.051             -0.159
# max           10.382                      25.368             10.755
#
#        word_freq_george  word_freq_cs  word_freq_random  word_freq_conference  \
# count          1000.000        1000.0            1000.0              1000.000
# mean              0.000           0.0               0.0                 0.000
# std               1.001           0.0               0.0                 1.001
# min              -0.268           0.0               0.0                -0.111
# 25%              -0.268           0.0               0.0                -0.111
# 50%              -0.268           0.0               0.0                -0.111
# 75%              -0.268           0.0               0.0                -0.111
# max               8.811           0.0               0.0                21.440
#
#        word_freq_technology  char_freq_(
# count              1000.000     1000.000
# mean                  0.000       -0.000
# std                   1.001        1.001
# min                  -0.246       -0.599
# 25%                  -0.246       -0.599
# 50%                  -0.246       -0.327
# 75%                  -0.246        0.184
# max                  11.371       11.903
#
# [8 rows x 61 columns]

# %% [markdown]
# #### KNN 적용:

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.5, random_state=3)

# %%
print(X_train)
print(Y_train)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# [[-0.60450963 -0.20449169 -0.1484211  ... -0.1111584  -0.24558099
#   -0.5993387 ]
#  [-0.60450963 -0.20449169 -0.1484211  ... -0.1111584  -0.24558099
#   -0.25924496]
#  [-0.60450963 -0.20449169 -0.1484211  ... -0.1111584  -0.24558099
#   -0.5993387 ]
#  ...
#  [-0.06814115 -0.20449169 -0.1484211  ... -0.1111584  -0.24558099
#   -0.00417465]
#  [-0.60450963 -0.20449169 -0.1484211  ... -0.1111584  -0.24558099
#   -0.5993387 ]
#  [ 0.37883259 -0.20449169 -0.1484211  ... -0.1111584  -0.24558099
#   -0.5993387 ]]
# ['no' 'yes' 'no' 'yes' 'no' 'yes' 'no' 'yes' 'yes' 'no' 'yes' 'no' 'no'
#  'yes' 'no' 'yes' 'yes' 'yes' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'no'
#  'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'yes' 'no' 'yes' 'no' 'no' 'no' 'no'
#  'no' 'yes' 'no' 'no' 'no' 'no' 'yes' 'yes' 'no' 'yes' 'yes' 'yes' 'yes'
#  'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'yes' 'no' 'no' 'no' 'no' 'no' 'no'
#  'no' 'no' 'yes' 'yes' 'no' 'yes' 'no' 'no' 'yes' 'no' 'no' 'no' 'yes'
#  'no' 'no' 'no' 'yes' 'no' 'yes' 'no' 'no' 'yes' 'no' 'no' 'yes' 'no' 'no'
#  'yes' 'no' 'no' 'yes' 'no' 'yes' 'no' 'yes' 'no' 'yes' 'yes' 'no' 'yes'
#  'yes' 'no' 'yes' 'no' 'no' 'no' 'no' 'yes' 'no' 'no' 'yes' 'no' 'yes'
#  'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'yes'
#  'yes' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no'
#  'yes' 'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'yes'
#  'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no'
#  'yes' 'no' 'yes' 'no' 'yes' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no'
#  'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'no' 'yes' 'no' 'no'
#  'no' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'yes' 'no' 'no' 'no' 'no'
#  'yes' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'yes' 'no' 'no' 'no' 'no' 'no'
#  'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'yes'
#  'yes' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'yes' 'no' 'no'
#  'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no' 'no'
#  'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'no' 'yes' 'no' 'yes'
#  'no' 'no' 'no' 'yes' 'yes' 'yes' 'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no'
#  'no' 'no' 'no' 'no' 'yes' 'yes' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no'
#  'no' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'yes' 'no' 'no' 'yes' 'no' 'no'
#  'yes' 'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'no' 'no'
#  'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'yes' 'yes' 'yes' 'no' 'yes'
#  'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'no'
#  'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'yes' 'no'
#  'no' 'no' 'no' 'no' 'no' 'yes' 'yes' 'yes' 'no' 'no' 'yes' 'no' 'no' 'no'
#  'yes' 'no' 'no' 'yes' 'no' 'yes' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'no'
#  'yes' 'yes' 'no' 'yes' 'yes' 'no' 'yes' 'no' 'no' 'no' 'yes' 'no' 'no'
#  'no' 'no' 'yes' 'no' 'yes' 'yes' 'no' 'yes' 'no' 'no' 'no' 'yes' 'no'
#  'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'yes' 'no' 'no' 'no'
#  'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'yes' 'yes' 'no' 'no' 'yes'
#  'yes' 'no' 'no' 'yes' 'no' 'no' 'yes' 'no' 'yes' 'no' 'no' 'yes' 'yes'
#  'no' 'no' 'no' 'yes' 'no' 'no' 'no' 'no' 'no' 'no' 'yes' 'no' 'yes' 'no'
#  'no' 'no' 'no' 'no' 'yes' 'no' 'yes']
# (500, 61)
# (500, 61)
# (500,)
# (500,)

# %% [markdown]
# KNN with n_neighbours = 5

# %%
knn5 = KNeighborsClassifier(n_neighbors=5)
knn5.fit(X_train, Y_train);
Y_pred = knn5.predict(X_test)
print(metrics.confusion_matrix(Y_test,Y_pred))
print("------------------------")
print( "Accuracy : " + str(np.round(metrics.accuracy_score(Y_test,Y_pred),3)))
# Out:
# [[349  25]
#  [ 37  89]]
# ------------------------
# Accuracy : 0.876

# %% [markdown]
# KNN with n_neighbours = 100

# %%
knn100 = KNeighborsClassifier(n_neighbors=100)
knn100.fit(X_train, Y_train);
Y_pred = knn100.predict(X_test)
print(metrics.confusion_matrix(Y_test,Y_pred))
print("------------------------")
print( "Accuracy : " + str(np.round(metrics.accuracy_score(Y_test,Y_pred),3)))
# Out:
# [[374   0]
#  [114  12]]
# ------------------------
# Accuracy : 0.772

# %% [markdown]
# #### KNN의 매개변수 (분산-편향 트레이드 오프):

# %%
accs = []
k_grid = np.arange(1,51,1)
for k in k_grid:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, Y_train);
    Y_pred = knn.predict(X_test)
    accs.append(metrics.accuracy_score(Y_test,Y_pred))

# %%
plt.scatter(k_grid,accs,c='red',marker='o',s=10,alpha=0.7)
plt.xlabel('k')
plt.ylabel('Accuracy')
plt.title('Accuracy vs k')
plt.show()

# %% [markdown]
# #### KNN의 매개변수 최적화:

# %%
k_grid = np.arange(1,51,1)
weights = ['uniform','distance']
parameters = {'n_neighbors':k_grid, 'weights':weights}

# %%
gridCV = GridSearchCV(KNeighborsClassifier(), parameters, cv=10)
gridCV.fit(X_train, Y_train);
best_k = gridCV.best_params_['n_neighbors']
best_w = gridCV.best_params_['weights']

# %%
print("Best k : " + str(best_k))
print("Best weight : " + best_w)
# Out:
# Best k : 4
# Best weight : distance

# %%
knn_best = KNeighborsClassifier(n_neighbors=best_k, weights = best_w)
knn_best.fit(X_train, Y_train);
Y_pred = knn_best.predict(X_test)
print( "Best Accuracy : " + str(np.round(metrics.accuracy_score(Y_test,Y_pred),3)))
# Out:
# Best Accuracy : 0.888

# %%
pca = PCA(n_components = 5)
X_pca = pca.fit_transform(X)
X_train, X_test, Y_train, Y_test = train_test_split(X_pca, Y, test_size=0.3, random_state=3)
knn_best = KNeighborsClassifier(n_neighbors=best_k, weights = best_w)
knn_best.fit(X_train, Y_train);
Y_pred = knn_best.predict(X_test)
print( "Best Accuracy : " + str(np.round(metrics.accuracy_score(Y_test,Y_pred),3)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-81906bfa1cc6> in <module>()
# ----> 1 pca = PCA(n_components = 5)
#       2 X_pca = pca.fit_transform(X)
#       3 X_train, X_test, Y_train, Y_test = train_test_split(X_pca, Y, test_size=0.3, random_state=3)
#       4 knn_best = KNeighborsClassifier(n_neighbors=best_k, weights = best_w)
#       5 knn_best.fit(X_train, Y_train);
#
# NameError: name 'PCA' is not defined
